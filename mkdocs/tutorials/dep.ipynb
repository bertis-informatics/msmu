# %% [markdown]
# # Differential Expression Analysis (DEA)

# %%
import msmu as mm

mdata = mm.read_h5mu("path/to/mdata.h5mu")

# %%
mdata

# %%
de = mm.tl.dea.permutation_test(mdata, modality="protein", ctrl="control", expr="experimental")

# %%
de.to_df()

# %%
de.plot_volcano()
