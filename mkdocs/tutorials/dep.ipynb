# %% [markdown]
# # Differential Expression Analysis (DEA)

# %%
import msmu as mm

mdata = mm.read_h5mu("path/to/mdata.h5mu")

# %%
de = mm.tl.run_de(
    mdata, 
    modality="protein", 
    category="treatment",
    ctrl="control", 
    expr="experimental",
    stat_method="welch",
    n_resamples=1000,
    fdr="empirical"
    )

# %%
de_res.to_df()

# %%
de_res.plot_volcano()
